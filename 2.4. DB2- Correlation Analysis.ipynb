# %%
#Correlation Analysis:  Summarize user responses to Determine the strength and direction of relationships between different variables, 
#such as training received and self-reported awareness levels in Next generation Sequencing by using relevant questions. 
import pandas as pd

# %%
file_path = "cleaneddata_NGS.csv"
df = pd.read_csv(file_path)

# %%
# Relevant columns to analyze
columns_to_analyze = [
 #1
    'Please indicate your role within the organization:',
    #2
    'How long have you been working in the NGS',
    #3
    'How often do you handle sensitive NGS data that could be targeted in a cybersecurity attack',
    #4
    'How often do you open emails from unknown senders as part of your work',
    #5
    'Have you ever used a personal USB drive or other external storage devices to transfer NGS data?',
    #6
    'Do you follow a process to verify the security of websites or links before accessing them, especially when related to NGS research',
   #7
    'Have you ever shared your login credentials with a colleague, even if you believed it was for a legitimate purpose',
   #8
    'In the event of receiving a suspicious email, what actions do you typically take (Select all that apply)',
    #9
    'Has there been an instance where you accessed NGS data from a public Wi-Fi network',
    #10
    'How frequently do you engage in non-work-related activities (e.g., browsing social media, personal emails) on devices used to access NGS data systems',
    #11
    'Do you regularly update your computer, smartphone, and other devices with the latest security patches and software updates',
    #12
    'Have you ever fallen victim to a phishing email or scam',
    #13
    'Are you aware of the potential cybersecurity risks associated with next-generation sequencing (NGS) technologies',
    #14
    'Do you understand the importance of securing genomic data generated by NGS technologies to protect patient privacy and confidentiality',
    #15
    'Are you familiar with common cybersecurity threats and vulnerabilities that can affect NGS data, such as data breaches, ransomware attacks, unauthorized access, fishing attack,  targeted attacks on genomic data or manipulation of sequencing results', 
    #16
    'Have you implemented data backup and disaster recovery plans to ensure the resilience of NGS data in the event of cyberattacks or system failures',
     #18
    'How confident are you in identifying a cybersecurity threat specific to NGS operations',
    #22
    'When handling sensitive NGS data, which of the following practices do you regularly follow (Select all that apply)',
    #23
    'Have you or anyone in your team ever detected a potential cybersecurity threat',
    #29
    'Have you ever received suspicious emails or messages that you suspect may target NGS data or systems',
    #31
    'Do you feel that cybersecurity should be a priority in your NGS relates tasks or experiments',
    #32
    'Do you use encryption techniques to secure NGS data during transmission and storage',
    #33
    'Do you collaborate with cybersecurity experts or professionals to enhance the security posture of NGS systems and data',
    #34
    'Do you feel that the  careless behaviors could lead to potential cybersecurity risks to the sensitive and private data in NGS',
    #35
    'Has there been a cybersecurity incident within your organization such as hacking, password stealing etc.,  that led to changes or enhancements in the training program or policy change',
    #39
    'What is your age group',
    #40
    'Have you heard about the term Bio-Cyber Security'
]

# %%
# Rename columns to be more formula-friendly
df.rename(columns={
    'Please indicate your role within the organization:': 'role_in_organization',
    'How long have you been working in the NGS':'time_duration',
    'How often do you handle sensitive NGS data that could be targeted in a cybersecurity attack': 'handle_sensitive_data',
    'How often do you open emails from unknown senders as part of your work':'open_emails',
    'Have you ever used a personal USB drive or other external storage devices to transfer NGS data':'usb_for_datatransfer',
    'Do you follow a process to verify the security of websites or links before accessing them, especially when related to NGS research':'website_verification',
    'Have you ever shared your login credentials with a colleague, even if you believed it was for a legitimate purpose':'sharing_credentials',
    'In the event of receiving a suspicious email, what actions do you typically take (Select all that apply)':'suspicious_email_actions',
    'Has there been an instance where you accessed NGS data from a public Wi-Fi network':'public_wifi',
    'How frequently do you engage in non-work-related activities (e.g., browsing social media, personal emails) on devices used to access NGS data systems':'activities',
    'Do you regularly update your computer, smartphone, and other devices with the latest security patches and software updates':'Updates',
    'Have you ever fallen victim to a phishing email or scam':'phishing',
    'Are you aware of the potential cybersecurity risks associated with next-generation sequencing (NGS) technologies': 'aware_attack',
    'Do you understand the importance of securing genomic data generated by NGS technologies to protect patient privacy and confidentiality':'securing_genomic_data',
    'Are you familiar with common cybersecurity threats and vulnerabilities that can affect NGS data, such as data breaches, ransomware attacks, unauthorized access, fishing attack,  targeted attacks on genomic data or manipulation of sequencing results': 'familiarity_cs', 
    'Have you implemented data backup and disaster recovery plans to ensure the resilience of NGS data in the event of cyberattacks or system failures': 'Backup',
    'How confident are you in identifying a cybersecurity threat specific to NGS operations': 'threat_identification',
    'When handling sensitive NGS data, which of the following practices do you regularly follow (Select all that apply)': 'handling',
     'Have you or anyone in your team ever detected a potential cybersecurity threat': 'threat_detection',
    'Have you ever received suspicious emails or messages that you suspect may target NGS data or systems': 'suspicious_emails',
    'Do you feel that cybersecurity should be a priority in your NGS relates tasks or experiments': 'cs_as_priority',
    'Do you use encryption techniques to secure NGS data during transmission and storage': 'encryption_techniques',
    'Do you collaborate with cybersecurity experts or professionals to enhance the security posture of NGS systems and data':'collaboration', 
    'Do you feel that the  careless behaviors could lead to potential cybersecurity risks to the sensitive and private data in NGS': 'careless_behaviour',
    'Has there been a cybersecurity incident within your organization such as hacking, password stealing etc.,  that led to changes or enhancements in the training program or policy change' : 'policy change',
    'What is your age group': 'age_group',
    'Have you heard about the term Bio-Cyber Security': 'Bio-Cyber_Security_familiarity'
}, inplace=True)

# %%
# Update columns_to_analyze with the renamed columns
columns_to_analyze = [
    'role_in_organization',
    'time_duration',
    'handle_sensitive_data',
    'open_emails',
    'usb_for_datatransfer',
    'website_verification',
    'sharing_credentials',
    'suspicious_email_actions',
    'public_wifi',
    'activities',
    'Updates',
    'phishing',
    'aware_attack',
    'securing_genomic_data',
    'familiarity_cs', 
    'Backup',
    'threat_identification',
    'handling',
    'threat_detection',
    'suspicious_emails',
    'cs_as_priority',
    'encryption_techniques',
    'collaboration', 
    'careless_behaviour',
    'policy change',
    'age_group',
    'Bio-Cyber_Security_familiarity'
]

# %%
# Mapping categorical responses to numerical values
def create_frequency_mapping(df, columns):
    unique_values = set()
    for col in columns:
        unique_values.update(df[col].dropna().unique())
    
    unique_values = sorted(list(unique_values))
    mapping = {value: index for index, value in enumerate(unique_values)}
    
    return mapping

# %%
# Create frequency mapping
frequency_mapping = create_frequency_mapping(df, columns_to_analyze)

# %%
# Convert relevant columns using the mapping
for col in columns_to_analyze:
    df[col] = df[col].map(frequency_mapping)

# %%
# Calculate the correlation matrix
correlation_matrix = df[columns_to_analyze].corr()

# %%
# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                 role_in_organization  time_duration  \
# role_in_organization                        1.000000      -0.127925
# time_duration                              -0.127925       1.000000
# handle_sensitive_data                      -0.059552      -0.010077
# open_emails                                -0.214270      -0.067180
# usb_for_datatransfer                       -0.292299      -0.151467
# website_verification                       -0.174860       0.088136
# sharing_credentials                        -0.144116      -0.158418
# suspicious_email_actions                   -0.227433       0.022350
# public_wifi                                -0.322685       0.101705
# activities                                 -0.093820       0.141452
# Updates                                    -0.203599       0.026042
# phishing                                   -0.483419       0.044997
# aware_attack                                     NaN            NaN
# securing_genomic_data                      -0.037195      -0.038098
# familiarity_cs                             -0.152180       0.061732
# Backup                                     -0.153859      -0.044954
# threat_identification                      -0.005756       0.048228
# handling                                    0.120702      -0.099132
# threat_detection                           -0.525955      -0.010045
# suspicious_emails                          -0.184092       0.004669
# cs_as_priority                             -0.025092       0.017125
# encryption_techniques                            NaN            NaN
# collaboration                              -0.160436       0.055744
# careless_behaviour                         -0.138429      -0.089775
# policy change                              -0.072979       0.011553
# age_group                                  -0.265336      -0.134731
# Bio-Cyber_Security_familiarity             -0.158221       0.060937
#
#                                 handle_sensitive_data  open_emails  \
# role_in_organization                        -0.059552    -0.214270
# time_duration                               -0.010077    -0.067180
# handle_sensitive_data                        1.000000    -0.019796
# open_emails                                 -0.019796     1.000000
# usb_for_datatransfer                        -0.019998     0.127950
# website_verification                        -0.094908     0.117801
# sharing_credentials                          0.092450     0.099382
# suspicious_email_actions                     0.149915    -0.015431
# public_wifi                                  0.007404     0.050252
# activities                                  -0.084515    -0.229361
# Updates                                      0.105483     0.268446
# phishing                                     0.114884     0.108398
# aware_attack                                      NaN          NaN
# securing_genomic_data                        0.131293     0.007258
# familiarity_cs                              -0.011115     0.150625
# Backup                                      -0.168547     0.233207
# threat_identification                        0.065785     0.031377
# handling                                     0.101078    -0.035203
# threat_detection                             0.060451     0.426371
# suspicious_emails                            0.039729     0.130915
# cs_as_priority                              -0.097255    -0.069064
# encryption_techniques                             NaN          NaN
# collaboration                                0.181225     0.186074
# careless_behaviour                          -0.045481    -0.164682
# policy change                                0.035234    -0.061338
# age_group                                    0.432203     0.356643
# Bio-Cyber_Security_familiarity               0.114259     0.048861
#
#                                 usb_for_datatransfer  website_verification  \
# role_in_organization                       -0.292299             -0.174860
# time_duration                              -0.151467              0.088136
# handle_sensitive_data                      -0.019998             -0.094908
# open_emails                                 0.127950              0.117801
# usb_for_datatransfer                        1.000000             -0.166700
# website_verification                       -0.166700              1.000000
# sharing_credentials                         0.218270             -0.082891
# suspicious_email_actions                    0.289946              0.063339
# public_wifi                                 0.289632              0.144417
# activities                                 -0.052941              0.085982
# Updates                                     0.010323              0.026430
# phishing                                    0.221759              0.283210
# aware_attack                                     NaN                   NaN
# securing_genomic_data                       0.354820             -0.019873
# familiarity_cs                              0.265467              0.241551
# Backup                                      0.289695              0.013331
# threat_identification                      -0.173696              0.100119
# handling                                   -0.096452              0.004953
# threat_detection                            0.267398              0.215685
# suspicious_emails                           0.062474             -0.015386
# cs_as_priority                              0.053056              0.027011
# encryption_techniques                            NaN                   NaN
# collaboration                               0.080159             -0.131231
# careless_behaviour                          0.028802             -0.023786
# policy change                              -0.115323              0.020444
# age_group                                   0.134354              0.059436
# Bio-Cyber_Security_familiarity              0.008167             -0.201298
#
#                                 sharing_credentials  suspicious_email_actions  \
# role_in_organization                      -0.144116                 -0.227433
# time_duration                             -0.158418                  0.022350
# handle_sensitive_data                      0.092450                  0.149915
# open_emails                                0.099382                 -0.015431
# usb_for_datatransfer                       0.218270                  0.289946
# website_verification                      -0.082891                  0.063339
# sharing_credentials                        1.000000                  0.034861
# suspicious_email_actions                   0.034861                  1.000000
# public_wifi                                0.376281                  0.117372
# activities                                -0.047980                 -0.052977
# Updates                                    0.047223                 -0.045092
# phishing                                   0.212525                  0.025494
# aware_attack                                    NaN                       NaN
# securing_genomic_data                      0.055074                 -0.008852
# familiarity_cs                            -0.010666                  0.128995
# Backup                                     0.281219                  0.010978
# threat_identification                      0.060905                  0.086963
# handling                                  -0.067460                 -0.068119
# threat_detection                           0.103947                  0.246199
# suspicious_emails                          0.292257                  0.261898
# cs_as_priority                            -0.045291                  0.017800
# encryption_techniques                           NaN                       NaN
# collaboration                             -0.070732                  0.025434
# careless_behaviour                         0.013577                  0.027544
# policy change                             -0.166454                  0.056208
# age_group                                 -0.049746                  0.356106
# Bio-Cyber_Security_familiarity             0.181436                 -0.065907
#
#                                 public_wifi  activities  ...  handling  \
# role_in_organization              -0.322685   -0.093820  ...  0.120702
# time_duration                      0.101705    0.141452  ... -0.099132
# handle_sensitive_data              0.007404   -0.084515  ...  0.101078
# open_emails                        0.050252   -0.229361  ... -0.035203
# usb_for_datatransfer               0.289632   -0.052941  ... -0.096452
# website_verification               0.144417    0.085982  ...  0.004953
# sharing_credentials                0.376281   -0.047980  ... -0.067460
# suspicious_email_actions           0.117372   -0.052977  ... -0.068119
# public_wifi                        1.000000    0.142626  ... -0.108035
# activities                         0.142626    1.000000  ...  0.017040
# Updates                            0.059941    0.032399  ... -0.009823
# phishing                           0.559212    0.194714  ...  0.050412
# aware_attack                            NaN         NaN  ...       NaN
# securing_genomic_data              0.213241    0.090717  ...  0.010426
# familiarity_cs                     0.124506    0.043416  ... -0.048051
# Backup                             0.167854    0.073892  ...  0.373172
# threat_identification              0.050801   -0.031393  ... -0.066405
# handling                          -0.108035    0.017040  ...  1.000000
# threat_detection                   0.428652   -0.121676  ... -0.083432
# suspicious_emails                  0.298076   -0.030957  ... -0.074124
# cs_as_priority                     0.027245   -0.025834  ... -0.109723
# encryption_techniques                   NaN         NaN  ...       NaN
# collaboration                     -0.085465   -0.026776  ...  0.066478
# careless_behaviour                 0.249803   -0.050098  ...  0.104766
# policy change                     -0.016788    0.028204  ...  0.111874
# age_group                          0.142625   -0.245436  ...  0.061740
# Bio-Cyber_Security_familiarity     0.311481    0.201715  ... -0.111907
#
#                                 threat_detection  suspicious_emails  \
# role_in_organization                   -0.525955          -0.184092
# time_duration                          -0.010045           0.004669
# handle_sensitive_data                   0.060451           0.039729
# open_emails                             0.426371           0.130915
# usb_for_datatransfer                    0.267398           0.062474
# website_verification                    0.215685          -0.015386
# sharing_credentials                     0.103947           0.292257
# suspicious_email_actions                0.246199           0.261898
# public_wifi                             0.428652           0.298076
# activities                             -0.121676          -0.030957
# Updates                                 0.194908           0.050409
# phishing                                0.486907           0.265100
# aware_attack                                 NaN                NaN
# securing_genomic_data                   0.114776           0.339173
# familiarity_cs                          0.441915           0.162691
# Backup                                  0.276789           0.183303
# threat_identification                  -0.082035          -0.093759
# handling                               -0.083432          -0.074124
# threat_detection                        1.000000           0.229701
# suspicious_emails                       0.229701           1.000000
# cs_as_priority                         -0.024318           0.242553
# encryption_techniques                        NaN                NaN
# collaboration                           0.279825          -0.087770
# careless_behaviour                      0.047052           0.188060
# policy change                           0.145308          -0.060318
# age_group                               0.511513           0.239127
# Bio-Cyber_Security_familiarity          0.141933           0.042765
#
#                                 cs_as_priority  encryption_techniques  \
# role_in_organization                 -0.025092                    NaN
# time_duration                         0.017125                    NaN
# handle_sensitive_data                -0.097255                    NaN
# open_emails                          -0.069064                    NaN
# usb_for_datatransfer                  0.053056                    NaN
# website_verification                  0.027011                    NaN
# sharing_credentials                  -0.045291                    NaN
# suspicious_email_actions              0.017800                    NaN
# public_wifi                           0.027245                    NaN
# activities                           -0.025834                    NaN
# Updates                              -0.093903                    NaN
# phishing                             -0.023030                    NaN
# aware_attack                               NaN                    NaN
# securing_genomic_data                 0.201275                    NaN
# familiarity_cs                        0.195310                    NaN
# Backup                               -0.038317                    NaN
# threat_identification                -0.105170                    NaN
# handling                             -0.109723                    NaN
# threat_detection                     -0.024318                    NaN
# suspicious_emails                     0.242553                    NaN
# cs_as_priority                        1.000000                    NaN
# encryption_techniques                      NaN                    NaN
# collaboration                        -0.098168                    NaN
# careless_behaviour                    0.590706                    NaN
# policy change                        -0.123382                    NaN
# age_group                            -0.024805                    NaN
# Bio-Cyber_Security_familiarity        0.014055                    NaN
#
#                                 collaboration  careless_behaviour  \
# role_in_organization                -0.160436           -0.138429
# time_duration                        0.055744           -0.089775
# handle_sensitive_data                0.181225           -0.045481
# open_emails                          0.186074           -0.164682
# usb_for_datatransfer                 0.080159            0.028802
# website_verification                -0.131231           -0.023786
# sharing_credentials                 -0.070732            0.013577
# suspicious_email_actions             0.025434            0.027544
# public_wifi                         -0.085465            0.249803
# activities                          -0.026776           -0.050098
# Updates                              0.095103            0.004266
# phishing                             0.107389           -0.001304
# aware_attack                              NaN                 NaN
# securing_genomic_data                0.119544            0.063610
# familiarity_cs                       0.337565            0.066026
# Backup                               0.379834           -0.005444
# threat_identification               -0.248513           -0.137640
# handling                             0.066478            0.104766
# threat_detection                     0.279825            0.047052
# suspicious_emails                   -0.087770            0.188060
# cs_as_priority                      -0.098168            0.590706
# encryption_techniques                     NaN                 NaN
# collaboration                        1.000000           -0.093196
# careless_behaviour                  -0.093196            1.000000
# policy change                        0.013311           -0.083928
# age_group                            0.191129           -0.001527
# Bio-Cyber_Security_familiarity       0.090326            0.191464
#
#                                 policy change  age_group  \
# role_in_organization                -0.072979  -0.265336
# time_duration                        0.011553  -0.134731
# handle_sensitive_data                0.035234   0.432203
# open_emails                         -0.061338   0.356643
# usb_for_datatransfer                -0.115323   0.134354
# website_verification                 0.020444   0.059436
# sharing_credentials                 -0.166454  -0.049746
# suspicious_email_actions             0.056208   0.356106
# public_wifi                         -0.016788   0.142625
# activities                           0.028204  -0.245436
# Updates                             -0.063575   0.075646
# phishing                             0.028240   0.334483
# aware_attack                              NaN        NaN
# securing_genomic_data               -0.195024   0.210642
# familiarity_cs                      -0.060987   0.167947
# Backup                              -0.250520   0.074887
# threat_identification                0.088910  -0.117313
# handling                             0.111874   0.061740
# threat_detection                     0.145308   0.511513
# suspicious_emails                   -0.060318   0.239127
# cs_as_priority                      -0.123382  -0.024805
# encryption_techniques                     NaN        NaN
# collaboration                        0.013311   0.191129
# careless_behaviour                  -0.083928  -0.001527
# policy change                        1.000000   0.197637
# age_group                            0.197637   1.000000
# Bio-Cyber_Security_familiarity      -0.122103  -0.032759
#
#                                 Bio-Cyber_Security_familiarity
# role_in_organization                                 -0.158221
# time_duration                                         0.060937
# handle_sensitive_data                                 0.114259
# open_emails                                           0.048861
# usb_for_datatransfer                                  0.008167
# website_verification                                 -0.201298
# sharing_credentials                                   0.181436
# suspicious_email_actions                             -0.065907
# public_wifi                                           0.311481
# activities                                            0.201715
# Updates                                              -0.011869
# phishing                                             -0.020711
# aware_attack                                               NaN
# securing_genomic_data                                 0.177357
# familiarity_cs                                        0.193625
# Backup                                               -0.131961
# threat_identification                                 0.021436
# handling                                             -0.111907
# threat_detection                                      0.141933
# suspicious_emails                                     0.042765
# cs_as_priority                                        0.014055
# encryption_techniques                                      NaN
# collaboration                                         0.090326
# careless_behaviour                                    0.191464
# policy change                                        -0.122103
# age_group                                            -0.032759
# Bio-Cyber_Security_familiarity                        1.000000
#
# [27 rows x 27 columns]
