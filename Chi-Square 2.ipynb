# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
# Load the CSV file
file_path = "cleaneddata_NGS.csv"
df = pd.read_csv(file_path)

# %%
# Relevant columns to analyze
columns_to_analyze = [
    'How often does your organization provide cybersecurity training specifically tailored to NGS operations',  # Q5
    'How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security',  # Q6
    'How confident are you in identifying a cybersecurity threat specific to NGS operations',  # Q7
    'How relevant do you find the cybersecurity training content to your day-to-day responsibilities',  # Q8
    'Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned',  # Q9
    'Have you or anyone in your team ever detected a potential cybersecurity threat'  # Q10
]

# Rename columns for easier reference

#df.rename(columns={
#    'How often does your organization provide cybersecurity training specifically tailored to NGS operations': 'training_frequency',
#    'How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security': 'training_participation',
#    'How confident are you in identifying a cybersecurity threat specific to NGS operations': 'threat_identification_confidence',
#    'How relevant do you find the cybersecurity training content to your day-to-day responsibilities': 'training_relevance',
#    'Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned': 'applied_knowledge',
#    'Have you or anyone in your team ever detected a potential cybersecurity threat to NGS or other sensitive data?': 'detected_threat'
#}, inplace=True)

# Perform Chi-Square tests for each pair of questions
results = {}

# %%
for col1 in columns_to_analyze:
    for col2 in columns_to_analyze:
        if col1 != col2:
            # Create a contingency table
            contingency_table = pd.crosstab(df[col1], df[col2])
            
            # Perform the Chi-Square test
            chi2, p, dof, expected = chi2_contingency(contingency_table)
            
            # Store the results
            results[(col1, col2)] = {
                'Chi-Square Statistic': chi2,
                'p-value': p,
                'Degrees of Freedom': dof,
                'Expected Frequencies': expected
            }

# %%
# Display the results for each pair
for pair, result in results.items():
    print(f"Chi-Square Test between {pair[0]} and {pair[1]}:")
    print(f"Chi-Square Statistic: {result['Chi-Square Statistic']}")
    print(f"p-value: {result['p-value']}")
    print(f"Degrees of Freedom: {result['Degrees of Freedom']}")
    print("\nExpected Frequencies:")
    print(result['Expected Frequencies'])
    print("\n" + "-"*50 + "\n")
# Out:
# Chi-Square Test between How often does your organization provide cybersecurity training specifically tailored to NGS operations and How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security:
# Chi-Square Statistic: 47.118763156397556
# p-value: 4.44599528911815e-06
# Degrees of Freedom: 12
#
# Expected Frequencies:
# [[ 6.54545455  3.63636364  5.09090909  0.72727273]
#  [ 3.68181818  2.04545455  2.86363636  0.40909091]
#  [ 0.81818182  0.45454545  0.63636364  0.09090909]
#  [12.68181818  7.04545455  9.86363636  1.40909091]
#  [ 3.27272727  1.81818182  2.54545455  0.36363636]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often does your organization provide cybersecurity training specifically tailored to NGS operations and How confident are you in identifying a cybersecurity threat specific to NGS operations:
# Chi-Square Statistic: 13.335290164452877
# p-value: 0.34514865012322243
# Degrees of Freedom: 12
#
# Expected Frequencies:
# [[ 8.24242424  4.12121212  0.96969697  2.66666667]
#  [ 4.63636364  2.31818182  0.54545455  1.5       ]
#  [ 1.03030303  0.51515152  0.12121212  0.33333333]
#  [15.96969697  7.98484848  1.87878788  5.16666667]
#  [ 4.12121212  2.06060606  0.48484848  1.33333333]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often does your organization provide cybersecurity training specifically tailored to NGS operations and How relevant do you find the cybersecurity training content to your day-to-day responsibilities:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[16.]
#  [ 9.]
#  [ 2.]
#  [31.]
#  [ 8.]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often does your organization provide cybersecurity training specifically tailored to NGS operations and Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned:
# Chi-Square Statistic: 38.458285330261134
# p-value: 0.00012918822421168196
# Degrees of Freedom: 12
#
# Expected Frequencies:
# [[ 1.6969697   5.81818182  3.39393939  5.09090909]
#  [ 0.95454545  3.27272727  1.90909091  2.86363636]
#  [ 0.21212121  0.72727273  0.42424242  0.63636364]
#  [ 3.28787879 11.27272727  6.57575758  9.86363636]
#  [ 0.84848485  2.90909091  1.6969697   2.54545455]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often does your organization provide cybersecurity training specifically tailored to NGS operations and Have you or anyone in your team ever detected a potential cybersecurity threat:
# Chi-Square Statistic: 27.79153831802682
# p-value: 0.0005155531820073705
# Degrees of Freedom: 8
#
# Expected Frequencies:
# [[ 2.90909091 11.39393939  1.6969697 ]
#  [ 1.63636364  6.40909091  0.95454545]
#  [ 0.36363636  1.42424242  0.21212121]
#  [ 5.63636364 22.07575758  3.28787879]
#  [ 1.45454545  5.6969697   0.84848485]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security and How often does your organization provide cybersecurity training specifically tailored to NGS operations:
# Chi-Square Statistic: 47.11876315639756
# p-value: 4.445995289118136e-06
# Degrees of Freedom: 12
#
# Expected Frequencies:
# [[ 6.54545455  3.68181818  0.81818182 12.68181818  3.27272727]
#  [ 3.63636364  2.04545455  0.45454545  7.04545455  1.81818182]
#  [ 5.09090909  2.86363636  0.63636364  9.86363636  2.54545455]
#  [ 0.72727273  0.40909091  0.09090909  1.40909091  0.36363636]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security and How confident are you in identifying a cybersecurity threat specific to NGS operations:
# Chi-Square Statistic: 7.993650793650794
# p-value: 0.5347861922621712
# Degrees of Freedom: 9
#
# Expected Frequencies:
# [[13.90909091  6.95454545  1.63636364  4.5       ]
#  [ 7.72727273  3.86363636  0.90909091  2.5       ]
#  [10.81818182  5.40909091  1.27272727  3.5       ]
#  [ 1.54545455  0.77272727  0.18181818  0.5       ]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security and How relevant do you find the cybersecurity training content to your day-to-day responsibilities:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[27.]
#  [15.]
#  [21.]
#  [ 3.]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security and Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned:
# Chi-Square Statistic: 25.671655328798188
# p-value: 0.0023114618682144993
# Degrees of Freedom: 9
#
# Expected Frequencies:
# [[2.86363636 9.81818182 5.72727273 8.59090909]
#  [1.59090909 5.45454545 3.18181818 4.77272727]
#  [2.22727273 7.63636364 4.45454545 6.68181818]
#  [0.31818182 1.09090909 0.63636364 0.95454545]]
#
# --------------------------------------------------
#
# Chi-Square Test between How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security and Have you or anyone in your team ever detected a potential cybersecurity threat:
# Chi-Square Statistic: 20.22891880156318
# p-value: 0.0025211245373517152
# Degrees of Freedom: 6
#
# Expected Frequencies:
# [[ 4.90909091 19.22727273  2.86363636]
#  [ 2.72727273 10.68181818  1.59090909]
#  [ 3.81818182 14.95454545  2.22727273]
#  [ 0.54545455  2.13636364  0.31818182]]
#
# --------------------------------------------------
#
# Chi-Square Test between How confident are you in identifying a cybersecurity threat specific to NGS operations and How often does your organization provide cybersecurity training specifically tailored to NGS operations:
# Chi-Square Statistic: 13.335290164452879
# p-value: 0.3451486501232223
# Degrees of Freedom: 12
#
# Expected Frequencies:
# [[ 8.24242424  4.63636364  1.03030303 15.96969697  4.12121212]
#  [ 4.12121212  2.31818182  0.51515152  7.98484848  2.06060606]
#  [ 0.96969697  0.54545455  0.12121212  1.87878788  0.48484848]
#  [ 2.66666667  1.5         0.33333333  5.16666667  1.33333333]]
#
# --------------------------------------------------
#
# Chi-Square Test between How confident are you in identifying a cybersecurity threat specific to NGS operations and How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security:
# Chi-Square Statistic: 7.993650793650794
# p-value: 0.5347861922621712
# Degrees of Freedom: 9
#
# Expected Frequencies:
# [[13.90909091  7.72727273 10.81818182  1.54545455]
#  [ 6.95454545  3.86363636  5.40909091  0.77272727]
#  [ 1.63636364  0.90909091  1.27272727  0.18181818]
#  [ 4.5         2.5         3.5         0.5       ]]
#
# --------------------------------------------------
#
# Chi-Square Test between How confident are you in identifying a cybersecurity threat specific to NGS operations and How relevant do you find the cybersecurity training content to your day-to-day responsibilities:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[34.]
#  [17.]
#  [ 4.]
#  [11.]]
#
# --------------------------------------------------
#
# Chi-Square Test between How confident are you in identifying a cybersecurity threat specific to NGS operations and Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned:
# Chi-Square Statistic: 18.163340336134457
# p-value: 0.03332510316935155
# Degrees of Freedom: 9
#
# Expected Frequencies:
# [[ 3.60606061 12.36363636  7.21212121 10.81818182]
#  [ 1.8030303   6.18181818  3.60606061  5.40909091]
#  [ 0.42424242  1.45454545  0.84848485  1.27272727]
#  [ 1.16666667  4.          2.33333333  3.5       ]]
#
# --------------------------------------------------
#
# Chi-Square Test between How confident are you in identifying a cybersecurity threat specific to NGS operations and Have you or anyone in your team ever detected a potential cybersecurity threat:
# Chi-Square Statistic: 3.8714911496513498
# p-value: 0.6940621180632465
# Degrees of Freedom: 6
#
# Expected Frequencies:
# [[ 6.18181818 24.21212121  3.60606061]
#  [ 3.09090909 12.10606061  1.8030303 ]
#  [ 0.72727273  2.84848485  0.42424242]
#  [ 2.          7.83333333  1.16666667]]
#
# --------------------------------------------------
#
# Chi-Square Test between How relevant do you find the cybersecurity training content to your day-to-day responsibilities and How often does your organization provide cybersecurity training specifically tailored to NGS operations:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[16.  9.  2. 31.  8.]]
#
# --------------------------------------------------
#
# Chi-Square Test between How relevant do you find the cybersecurity training content to your day-to-day responsibilities and How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[27. 15. 21.  3.]]
#
# --------------------------------------------------
#
# Chi-Square Test between How relevant do you find the cybersecurity training content to your day-to-day responsibilities and How confident are you in identifying a cybersecurity threat specific to NGS operations:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[34. 17.  4. 11.]]
#
# --------------------------------------------------
#
# Chi-Square Test between How relevant do you find the cybersecurity training content to your day-to-day responsibilities and Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[ 7. 24. 14. 21.]]
#
# --------------------------------------------------
#
# Chi-Square Test between How relevant do you find the cybersecurity training content to your day-to-day responsibilities and Have you or anyone in your team ever detected a potential cybersecurity threat:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[12. 47.  7.]]
#
# --------------------------------------------------
#
# Chi-Square Test between Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned and How often does your organization provide cybersecurity training specifically tailored to NGS operations:
# Chi-Square Statistic: 38.458285330261134
# p-value: 0.00012918822421168196
# Degrees of Freedom: 12
#
# Expected Frequencies:
# [[ 1.6969697   0.95454545  0.21212121  3.28787879  0.84848485]
#  [ 5.81818182  3.27272727  0.72727273 11.27272727  2.90909091]
#  [ 3.39393939  1.90909091  0.42424242  6.57575758  1.6969697 ]
#  [ 5.09090909  2.86363636  0.63636364  9.86363636  2.54545455]]
#
# --------------------------------------------------
#
# Chi-Square Test between Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned and How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security:
# Chi-Square Statistic: 25.671655328798188
# p-value: 0.0023114618682144993
# Degrees of Freedom: 9
#
# Expected Frequencies:
# [[2.86363636 1.59090909 2.22727273 0.31818182]
#  [9.81818182 5.45454545 7.63636364 1.09090909]
#  [5.72727273 3.18181818 4.45454545 0.63636364]
#  [8.59090909 4.77272727 6.68181818 0.95454545]]
#
# --------------------------------------------------
#
# Chi-Square Test between Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned and How confident are you in identifying a cybersecurity threat specific to NGS operations:
# Chi-Square Statistic: 18.163340336134453
# p-value: 0.03332510316935161
# Degrees of Freedom: 9
#
# Expected Frequencies:
# [[ 3.60606061  1.8030303   0.42424242  1.16666667]
#  [12.36363636  6.18181818  1.45454545  4.        ]
#  [ 7.21212121  3.60606061  0.84848485  2.33333333]
#  [10.81818182  5.40909091  1.27272727  3.5       ]]
#
# --------------------------------------------------
#
# Chi-Square Test between Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned and How relevant do you find the cybersecurity training content to your day-to-day responsibilities:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[ 7.]
#  [24.]
#  [14.]
#  [21.]]
#
# --------------------------------------------------
#
# Chi-Square Test between Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned and Have you or anyone in your team ever detected a potential cybersecurity threat:
# Chi-Square Statistic: 10.73520950933565
# p-value: 0.0969130306908825
# Degrees of Freedom: 6
#
# Expected Frequencies:
# [[ 1.27272727  4.98484848  0.74242424]
#  [ 4.36363636 17.09090909  2.54545455]
#  [ 2.54545455  9.96969697  1.48484848]
#  [ 3.81818182 14.95454545  2.22727273]]
#
# --------------------------------------------------
#
# Chi-Square Test between Have you or anyone in your team ever detected a potential cybersecurity threat and How often does your organization provide cybersecurity training specifically tailored to NGS operations:
# Chi-Square Statistic: 27.79153831802682
# p-value: 0.0005155531820073705
# Degrees of Freedom: 8
#
# Expected Frequencies:
# [[ 2.90909091  1.63636364  0.36363636  5.63636364  1.45454545]
#  [11.39393939  6.40909091  1.42424242 22.07575758  5.6969697 ]
#  [ 1.6969697   0.95454545  0.21212121  3.28787879  0.84848485]]
#
# --------------------------------------------------
#
# Chi-Square Test between Have you or anyone in your team ever detected a potential cybersecurity threat and How often do you participate in cybersecurity training or awareness programs specifically tailored for NGS data security:
# Chi-Square Statistic: 20.22891880156318
# p-value: 0.0025211245373517152
# Degrees of Freedom: 6
#
# Expected Frequencies:
# [[ 4.90909091  2.72727273  3.81818182  0.54545455]
#  [19.22727273 10.68181818 14.95454545  2.13636364]
#  [ 2.86363636  1.59090909  2.22727273  0.31818182]]
#
# --------------------------------------------------
#
# Chi-Square Test between Have you or anyone in your team ever detected a potential cybersecurity threat and How confident are you in identifying a cybersecurity threat specific to NGS operations:
# Chi-Square Statistic: 3.8714911496513498
# p-value: 0.6940621180632465
# Degrees of Freedom: 6
#
# Expected Frequencies:
# [[ 6.18181818  3.09090909  0.72727273  2.        ]
#  [24.21212121 12.10606061  2.84848485  7.83333333]
#  [ 3.60606061  1.8030303   0.42424242  1.16666667]]
#
# --------------------------------------------------
#
# Chi-Square Test between Have you or anyone in your team ever detected a potential cybersecurity threat and How relevant do you find the cybersecurity training content to your day-to-day responsibilities:
# Chi-Square Statistic: 0.0
# p-value: 1.0
# Degrees of Freedom: 0
#
# Expected Frequencies:
# [[12.]
#  [47.]
#  [ 7.]]
#
# --------------------------------------------------
#
# Chi-Square Test between Have you or anyone in your team ever detected a potential cybersecurity threat and Since the last cybersecurity training session, have you encountered situations where you applied the knowledge learned:
# Chi-Square Statistic: 10.735209509335649
# p-value: 0.09691303069088252
# Degrees of Freedom: 6
#
# Expected Frequencies:
# [[ 1.27272727  4.36363636  2.54545455  3.81818182]
#  [ 4.98484848 17.09090909  9.96969697 14.95454545]
#  [ 0.74242424  2.54545455  1.48484848  2.22727273]]
#
# --------------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the table
data = {
    'Test': ['Q5 vs Q6', 'Q5 vs Q7', 'Q5 vs Q8', 'Q5 vs Q9', 'Q5 vs Q10', 
             'Q6 vs Q7', 'Q6 vs Q8', 'Q6 vs Q9', 'Q6 vs Q10', 'Q7 vs Q8', 
             'Q9 vs Q10'],
    'Chi-Square (χ²)': [47.12, 13.34, 0.0, 38.46, 27.79, 7.99, 0.0, 25.67, 20.23, 0.0, 10.74],
    'P-value': [4.45E-06, 0.3451, 1.0, 0.00013, 0.00052, 0.5348, 1.0, 0.0023, 0.0025, 1.0, 0.09691],
    'df': [12, 12, 0, 12, 8, 9, 0, 9, 6, 0, 6],
    'Conclusion': ['Significant association', 'Not significant', 'Not significant (no variability)', 
                   'Significant association', 'Significant association', 'Not significant', 
                   'Not significant (no variability)', 'Significant association', 
                   'Significant association', 'Not significant (no variability)', 'Not significant']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(10, 8))
sns.barplot(x='Chi-Square (χ²)', y='Test', hue='Conclusion', data=df, palette='Set1', dodge=False)

# Annotating the p-values on the bars
for index, row in df.iterrows():
    plt.text(row['Chi-Square (χ²)'] + 1, index, f"p={row['P-value']:.1e}", color='black', va="center")

# Customize the plot
plt.title('Graphical Analysis of Chi-Square Test Results')
plt.xlabel('Chi-Square (χ²)')
plt.ylabel('Test')
plt.legend(title='Conclusion', bbox_to_anchor=(1, 1))
plt.tight_layout()

# Display the plot
plt.show()
